# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %%
import csv

# %%
whale_returns_csv = Path("whale_returns.csv")
whale_returns = pd.read_csv(
      whale_returns_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)
whale_returns = whale_returns.sort_index()
whale_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
whale_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
whale_returns.dropna(inplace=True)
whale_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %%
algo_returns_csv = Path("algo_returns.csv")
algo_returns = pd.read_csv(
      algo_returns_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)
algo_returns = algo_returns.sort_index()
algo_returns.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
algo_returns.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
sp500_history_csv = Path("sp500_history.csv")
sp500_history = pd.read_csv(
      sp500_history_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)
sp500_history = sp500_history.sort_index()
sp500_history.head()
# Out:
#                Close
# Date
# 2012-10-01  $1444.49
# 2012-10-02  $1445.75
# 2012-10-03  $1450.99
# 2012-10-04  $1461.40
# 2012-10-05  $1460.93

# %%
sp500_history.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
sp500_history.dtypes
# Out:
# Close    object
# dtype: object

# %%
sp500_history["Close"] = sp500_history["Close"].str.replace('$','')
sp500_history["Close"] = sp500_history["Close"].astype('float')
sp500_history.dtypes
# Out:
# Close    float64
# dtype: object

# %%
sp500_returns = sp500_history.pct_change()
sp500_returns.head()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322

# %%
sp500_returns.dropna(inplace=True)
sp500_returns.head()
# Out:
#                Close
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %%
sp500_returns.rename(columns={"Close":"S&P 500"}, inplace=True)
sp500_returns.head()
# Out:
#              S&P 500
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %%
pd.concat
# Out:
# <function pandas.core.reshape.concat.concat(objs: Union[Iterable[Union[ForwardRef('DataFrame'), ForwardRef('Series')]], Mapping[Union[Hashable, NoneType], Union[ForwardRef('DataFrame'), ForwardRef('Series')]]], axis=0, join='outer', ignore_index: bool = False, keys=None, levels=None, names=None, verify_integrity: bool = False, sort: bool = False, copy: bool = True) -> Union[ForwardRef('DataFrame'), ForwardRef('Series')]>

# %%
all_portfolios = pd.concat([whale_returns, algo_returns, sp500_returns], axis="columns", join="inner")
all_portfolios.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2   S&P 500
# Date
# 2015-03-03 -0.000949 -0.004539
# 2015-03-04  0.002416 -0.004389
# 2015-03-05  0.004323  0.001196
# 2015-03-06 -0.011460 -0.014174
# 2015-03-09  0.001303  0.003944

# %%
all_portfolios.plot(figsize=(20, 10), title="Daily Returns")

# %%
cumulative_returns = (1 + all_portfolios).cumprod()
cumulative_returns.plot(figsize=(20, 10), title="Cumulative Returns")

# %%
all_portfolios.plot.box(figsize=(20, 10), title="Portfolios Returns")

# %%
all_portfolios.std()
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# S&P 500                        0.008554
# dtype: float64

# %%
sp500_risk = all_portfolios["S&P 500"].std()
all_portfolios.std() > sp500_risk
# Out:
# SOROS FUND MANAGEMENT LLC      False
# PAULSON & CO.INC.              False
# TIGER GLOBAL MANAGEMENT LLC     True
# BERKSHIRE HATHAWAY INC          True
# Algo 1                         False
# Algo 2                         False
# S&P 500                        False
# dtype: bool

# %%
all_portfolios.std() * np.sqrt(252)
# Out:
# SOROS FUND MANAGEMENT LLC      0.125335
# PAULSON & CO.INC.              0.111488
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# BERKSHIRE HATHAWAY INC         0.205077
# Algo 1                         0.120967
# Algo 2                         0.132430
# S&P 500                        0.135786
# dtype: float64

# %%
all_portfolios.rolling(window=21).std().plot(figsize=(20, 10), title="21 Days Rolling Standard Deviation")

# %%
corr_df = all_portfolios.corr()
corr_df.style.background_gradient(cmap="summer")
# Out:
# <style  type="text/css" >
#     #T_aba2e876_bdaf_11eb_a410_f48c50039d40row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row0_col1 {
#             background-color:  #96cb66;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row0_col2 {
#             background-color:  #79bc66;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row0_col3 {
#             background-color:  #a7d366;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row0_col4 {
#             background-color:  #309866;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row0_col5 {
#             background-color:  #c1e066;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row0_col6 {
#             background-color:  #c6e266;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row1_col0 {
#             background-color:  #8ec666;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row1_col2 {
#             background-color:  #52a866;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row1_col3 {
#             background-color:  #5bad66;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row1_col4 {
#             background-color:  #209066;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row1_col5 {
#             background-color:  #8cc666;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row1_col6 {
#             background-color:  #8ac466;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row2_col0 {
#             background-color:  #5aac66;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row2_col1 {
#             background-color:  #399c66;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row2_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row2_col3 {
#             background-color:  #2f9766;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row2_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row2_col5 {
#             background-color:  #4ea666;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row2_col6 {
#             background-color:  #7abc66;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row3_col0 {
#             background-color:  #a3d166;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row3_col1 {
#             background-color:  #60b066;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row3_col2 {
#             background-color:  #4fa766;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row3_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row3_col4 {
#             background-color:  #279366;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row3_col5 {
#             background-color:  #8fc766;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row3_col6 {
#             background-color:  #a7d366;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row4_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row4_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row4_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row4_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row4_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row4_col5 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row4_col6 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row5_col0 {
#             background-color:  #bede66;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row5_col1 {
#             background-color:  #8fc766;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row5_col2 {
#             background-color:  #69b466;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row5_col3 {
#             background-color:  #8fc766;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row5_col4 {
#             background-color:  #259266;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row5_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row5_col6 {
#             background-color:  #cde666;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row6_col0 {
#             background-color:  #c2e066;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row6_col1 {
#             background-color:  #8cc666;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row6_col2 {
#             background-color:  #8cc666;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row6_col3 {
#             background-color:  #a6d266;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row6_col4 {
#             background-color:  #239166;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row6_col5 {
#             background-color:  #cde666;
#             color:  #000000;
#         }    #T_aba2e876_bdaf_11eb_a410_f48c50039d40row6_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }</style><table id="T_aba2e876_bdaf_11eb_a410_f48c50039d40" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >SOROS FUND MANAGEMENT LLC</th>        <th class="col_heading level0 col1" >PAULSON & CO.INC. </th>        <th class="col_heading level0 col2" >TIGER GLOBAL MANAGEMENT LLC</th>        <th class="col_heading level0 col3" >BERKSHIRE HATHAWAY INC</th>        <th class="col_heading level0 col4" >Algo 1</th>        <th class="col_heading level0 col5" >Algo 2</th>        <th class="col_heading level0 col6" >S&P 500</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_aba2e876_bdaf_11eb_a410_f48c50039d40level0_row0" class="row_heading level0 row0" >SOROS FUND MANAGEMENT LLC</th>
#                         <td id="T_aba2e876_bdaf_11eb_a410_f48c50039d40row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_aba2e876_bdaf_11eb_a410_f48c50039d40row0_col1" class="data row0 col1" >0.699914</td>
#                         <td id="T_aba2e876_bdaf_11eb_a410_f48c50039d40row0_col2" class="data row0 col2" >0.561243</td>
#                         <td id="T_aba2e876_bdaf_11eb_a410_f48c50039d40row0_col3" class="data row0 col3" >0.754360</td>
#                         <td id="T_aba2e876_bdaf_11eb_a410_f48c50039d40row0_col4" class="data row0 col4" >0.321211</td>
#                         <td id="T_aba2e876_bdaf_11eb_a410_f48c50039d40row0_col5" class="data r

# %%
covariance = all_portfolios["BERKSHIRE HATHAWAY INC"].rolling(window=60).cov(all_portfolios["S&P 500"])
variance = all_portfolios["S&P 500"].rolling(60).var()
(covariance / variance).plot(figsize=(20, 10), title="Berkshire Hathaway Inc. Beta")

# %%
sharpe_ratios = (all_portfolios.mean() * 252) / (all_portfolios.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# S&P 500                        0.648267
# dtype: float64

# %%
sharpe_ratios.plot(kind="bar",title="Sharpe Ratios")
